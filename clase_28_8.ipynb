# %% [markdown]
# <a href="https://colab.research.google.com/github/judithdejesus/Integrador-Alkemy/blob/main/clase_28_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
ventas = pd.read_csv('ventas.csv')
ventas
# Out:
#    Producto  Precio  Impuesto  Unnamed: 3  Unnamed: 4  Unnamed: 5
# 0    Laptop   800.0      80.0         NaN         NaN         NaN
# 1  Teléfono   200.0      20.0         NaN         NaN         NaN
# 2    Tablet   750.0      75.0         NaN         NaN         NaN
# 3    Laptop   350.0      35.0         NaN         NaN         NaN
# 4  Teléfono   100.0      10.0         NaN         NaN         NaN
# 5    Tablet   150.0      15.0         NaN         NaN         NaN
# 6       NaN     NaN       NaN         NaN         NaN         NaN
# 7       NaN     NaN       NaN         NaN         NaN         NaN

# %%
ventas['Total'] = ventas['Precio'] + ventas['Impuesto']
ventas
# Out:
#    Producto  Precio  Impuesto  Unnamed: 3  Unnamed: 4  Unnamed: 5  Total
# 0    Laptop   800.0      80.0         NaN         NaN         NaN  880.0
# 1  Teléfono   200.0      20.0         NaN         NaN         NaN  220.0
# 2    Tablet   750.0      75.0         NaN         NaN         NaN  825.0
# 3    Laptop   350.0      35.0         NaN         NaN         NaN  385.0
# 4  Teléfono   100.0      10.0         NaN         NaN         NaN  110.0
# 5    Tablet   150.0      15.0         NaN         NaN         NaN  165.0
# 6       NaN     NaN       NaN         NaN         NaN         NaN    NaN
# 7       NaN     NaN       NaN         NaN         NaN         NaN    NaN

# %%
ventas['Descuento'] = ventas['Total'] * 0.9
ventas
# Out:
#    Producto  Precio  Impuesto  Unnamed: 3  Unnamed: 4  Unnamed: 5  Total  \
# 0    Laptop   800.0      80.0         NaN         NaN         NaN  880.0
# 1  Teléfono   200.0      20.0         NaN         NaN         NaN  220.0
# 2    Tablet   750.0      75.0         NaN         NaN         NaN  825.0
# 3    Laptop   350.0      35.0         NaN         NaN         NaN  385.0
# 4  Teléfono   100.0      10.0         NaN         NaN         NaN  110.0
# 5    Tablet   150.0      15.0         NaN         NaN         NaN  165.0
# 6       NaN     NaN       NaN         NaN         NaN         NaN    NaN
# 7       NaN     NaN       NaN         NaN         NaN         NaN    NaN
#
#    Descuento
# 0      792.0
# 1      198.0
# 2      742.5
# 3      346.5
# 4       99.0
# 5      148.5
# 6        NaN
# 7        NaN

# %%
agrupado = ventas.groupby('Producto').agg({'Total':'sum'})
agrupado
# Out:
#            Total
# Producto
# Laptop    1265.0
# Tablet     990.0
# Teléfono   330.0

# %%
ventas.loc[4]
# Out:
# Producto      Teléfono
# Precio           100.0
# Impuesto          10.0
# Unnamed: 3         NaN
# Unnamed: 4         NaN
# Unnamed: 5         NaN
# Total            110.0
# Descuento         99.0
# Name: 4, dtype: object

# %%
ventas.loc[:,'Impuesto']
# Out:
# 0    80.0
# 1    20.0
# 2    75.0
# 3    35.0
# 4    10.0
# 5    15.0
# 6     NaN
# 7     NaN
# Name: Impuesto, dtype: float64

# %%
ventas.loc[4,'Impuesto']
# Out:
# 10.0

# %%
ventas[0:2]
# Out:
#    Producto  Precio  Impuesto  Unnamed: 3  Unnamed: 4  Unnamed: 5  Total  \
# 0    Laptop   800.0      80.0         NaN         NaN         NaN  880.0
# 1  Teléfono   200.0      20.0         NaN         NaN         NaN  220.0
#
#    Descuento
# 0      792.0
# 1      198.0

# %%
ventas.loc[0:1]
# Out:
#    Producto  Precio  Impuesto  Unnamed: 3  Unnamed: 4  Unnamed: 5  Total  \
# 0    Laptop   800.0      80.0         NaN         NaN         NaN  880.0
# 1  Teléfono   200.0      20.0         NaN         NaN         NaN  220.0
#
#    Descuento
# 0      792.0
# 1      198.0

# %%
ventas.loc[:, ('Producto', 'Precio')]
# Out:
#    Producto  Precio
# 0    Laptop   800.0
# 1  Teléfono   200.0
# 2    Tablet   750.0
# 3    Laptop   350.0
# 4  Teléfono   100.0
# 5    Tablet   150.0
# 6       NaN     NaN
# 7       NaN     NaN

# %%
ventas.iloc[:,1:3]
# Out:
#    Precio  Impuesto
# 0   800.0      80.0
# 1   200.0      20.0
# 2   750.0      75.0
# 3   350.0      35.0
# 4   100.0      10.0
# 5   150.0      15.0
# 6     NaN       NaN
# 7     NaN       NaN

# %%
agrupado = ventas.groupby('Producto').agg({'Total':'sum'})
agrupado
# Out:
#            Total
# Producto
# Laptop    1265.0
# Tablet     990.0
# Teléfono   330.0

# %%
categorias = pd.read_csv('categorias.csv')
categorias
# Out:
#    Producto  ID_Categoria  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5
# 0    Laptop           1.0         NaN         NaN         NaN         NaN
# 1  Teléfono           2.0         NaN         NaN         NaN         NaN
# 2    Tablet           3.0         NaN         NaN         NaN         NaN
# 3       NaN           NaN         NaN         NaN         NaN         NaN
# 4       NaN           NaN         NaN         NaN         NaN         NaN
# 5       NaN           NaN         NaN         NaN         NaN         NaN
# 6       NaN           NaN         NaN         NaN         NaN         NaN
# 7       NaN           NaN         NaN         NaN         NaN         NaN

# %% [markdown]
# # Clase con Walter

# %%
import sqlite3 as sql
import pandas as pd

# %%
conn = sql.connect('ventas.db')
conn

# %%
cursor = conn.cursor()

# %%
query = '''

    CREATE TABLE productos (
    id_producto INT PRIMARY KEY,
    nombre_producto VARCHAR(100),
    precio_unitario DECIMAL(10, 2),
    stock INT
    );
      CREATE TABLE clientes (
    id_cliente INT PRIMARY KEY,
    nombre_cliente VARCHAR(100),
    direccion VARCHAR(200),
    ciudad VARCHAR(50)
    );
      CREATE TABLE ventas (
    id_venta INT PRIMARY KEY,
    fecha_venta DATE,
    id_cliente INT,
    total_venta DECIMAL(10, 2),
    FOREIGN KEY (id_cliente) REFERENCES clientes(id_cliente)
    );
'''

# %%
cursor.executescript(query)

# %%
inserts = '''
INSERT INTO productos (id_producto, nombre_producto, precio_unitario, stock) VALUES
(1, 'Producto 1', 10.50, 100),
(2, 'Producto 2', 15.25, 50),
(3, 'Producto 3', 20.00, 0);

INSERT INTO clientes (id_cliente, nombre_cliente, direccion, ciudad) VALUES
(1, 'Cliente 1', 'Calle 123, Ciudad A', 'Ciudad A'),
(2, 'Cliente 2', 'Avenida 456, Ciudad B', 'Ciudad B'),
(3, 'Cliente 3', 'Carretera 789, Ciudad C', 'Ciudad C');

INSERT INTO ventas (id_venta, fecha_venta, id_cliente, total_venta) VALUES
(1, '2023-07-01', 1, 100.00),
(2, '2023-07-02', 2, 50.00),
(3, '2023-07-03', 3, 75.50);

'''

# %%
cursor.executescript(inserts)

# %%
#Realiza una consulta para obtener todos los productos de la tabla "productos" que tengan stock.
consulta = '''
 SELECT nombre_producto FROM Productos WHERE stock != 0
'''

# %%
cursor.execute(consulta).fetchall()
# Out:
# [('Producto 1',), ('Producto 2',)]

# %%
pd.read_sql_query(consulta, conn)
# Out:
#   nombre_producto
# 0      Producto 1
# 1      Producto 2

# %%
#Realiza una consulta para obtener todas las ventas de la tabla "ventas" y carga los resultados en otro DataFrame de Pandas.
consulta2 = '''
  SELECT * FROM ventas
'''

# %%
cursor.execute(consulta2).fetchall()
# Out:
# [(1, '2023-07-01', 1, 100),
#  (2, '2023-07-02', 2, 50),
#  (3, '2023-07-03', 3, 75.5)]

# %%
df = pd.read_sql_query(consulta2, conn)
df
# Out:
#    id_venta fecha_venta  id_cliente  total_venta
# 0         1  2023-07-01           1        100.0
# 1         2  2023-07-02           2         50.0
# 2         3  2023-07-03           3         75.5

# %%
#Realiza una consulta para obtener todas las ventas que tengan un total superior o igual a 50.
consulta2 = df['total_venta']>=50.
consulta2
# Out:
# 0    True
# 1    True
# 2    True
# Name: total_venta, dtype: bool

# %%
# !pip install pyspark
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.8/310.8 MB 2.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pyspark: filename=pyspark-3.4.1-py2.py3-none-any.whl size=311285387 sha256=a7a07ef098fb8002f3dd23f98a5a8893287806351d600c4fbfa180d59bb3639a
#   Stored in directory: /root/.cache/pip/wheels/0d/77/a3/ff2f74cc9ab41f8f594dabf0579c2a7c6de920d584206e0834
# Successfully built pyspark
# ...

# %%
from pyspark.sql import *
from pyspark.sql.functions import *
from pyspark import SparkContext
from pyspark.sql import SQLContext

# %%
spark = SparkSession.builder.getOrCreate()

# %%
df = spark.read.csv('/content/flight_delays1.csv', header='false', inferSchema = True)
df.show()
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# <ipython-input-30-3f060649f2b0> in <cell line: 1>()
# ----> 1 df = spark.read.csv('/content/flight_delays1.csv', header='false', inferSchema = True)
#       2 df.show()
#
# /usr/local/lib/python3.10/dist-packages/pyspark/sql/readwriter.py in csv(self, path, schema, sep, encoding, quote, escape, comment, header, inferSchema, ignoreLeadingWhiteSpace, ignoreTrailingWhiteSpace, nullValue, nanValue, positiveInf, negativeInf, dateFormat, timestampFormat, maxColumns, maxCharsPerColumn, maxMalformedLogPerPartition, mode, columnNameOfCorruptRecord, multiLine, charToEscapeQuoteEscaping, samplingRatio, enforceSchema, emptyValue, locale, lineSep, pathGlobFilter, recursiveFileLookup, modifiedBefore, modifiedAfter, unescapedQuoteHandling)
#     725         if type(path) == list:
#     726             assert self._spark._sc._jvm is not None
# ...

# %%
filtered_df = df.filter(df._c13 > 100)
filtered_df.show()

# %%
columnas_a_eliminar = ["_c22", "_c23", "_c21"]
df = df.drop(*columnas_a_eliminar)
df.show()

# %%
df.count()

# %%
len(df.columns)

# %%
# !pip install mysql-connector-python
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.5/27.5 MB 32.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 409.8/409.8 kB 11.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-metadata 1.14.0 requires protobuf<4.21,>=3.20.3, but you have protobuf 4.21.12 which is incompatible.
# ...

# %%
import mysql.connector

# %%
connection = mysql.connector.connect(host='db4free.net', user = 'judith', password = 'alkemy123456', database = 'pruebaalkemy')

# %%
cursor = connection.cursor()

# %%
cursor.execute(
    '''
    SHOW databases;
    '''
)

# %%
consulta = cursor.fetchall()

# %%
for fila in consulta:
  print(fila)
# Out:
# ('db4free_sys',)
# ('information_schema',)
# ('performance_schema',)
# ('pruebaalkemy',)

# %%
cursor.execute(
    '''
    SHOW tables;
    '''
)
resultado = cursor.fetchall()
for fila in resultado:
  print(fila)
# Out:
# ('customers',)

# %%
cursor.execute(
    '''
    CREATE TABLE customers (
    id INT AUTO_INCREMENT PRIMARY KEY,
    first_name VARCHAR(50),
    last_name VARCHAR(50),
    email VARCHAR(100),
    phone VARCHAR(20),
    city VARCHAR(100)
);
    '''
)
resultado2 = cursor.fetchall()
for fila in resultado2:
  print(fila)
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/mysql/connector/connection_cext.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     632                 query = query.encode("utf-8")
# --> 633             self._cmysql.query(
#     634                 query,
#
# MySQLInterfaceError: Table 'customers' already exists
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-65-cd9ae025ee0d> in <cell line: 1>()
# ----> 1 cursor.execute(
#       2     '''
#       3     CREATE TABLE customers (
#       4     id INT AUTO_INCREMENT PRIMARY KEY,
#       5     first_name VARCHAR(50),
#
# /usr/local/lib/python3.10/dist-packages/mysql/connector/cursor_cext.py in execute(self, operation, params, multi)
#     328
# ...

# %%
cursor.execute(
  '''
    INSERT INTO customers (first_name, last_name, email, phone, city)
    VALUES
    ('John', 'Doe', 'john@example.com', '555-1234', 'Cordoba'),
    ('Jane', 'Smith', 'jane@example.com', '555-5678', 'Buenos Aires'),
    ('Michael', 'Johnson', 'michael@example.com', '555-9876', 'Buenos Aires'),
    ('Emily', 'Williams', 'emily@example.com', '555-6543', 'Cordoba'),
    ('David', 'Brown', 'david@example.com', '555-7890', 'Buenos Aires');
  '''
)
customers = cursor.fetchall()
for fila in customers:
  print(fila)

# %%
customers_result = 'SELECT * FROM customers;'
df = pd.read_sql_query(customers_result, connection)
df
# Out:
# <ipython-input-69-4b33795b0312>:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(customers_result, connection)
#    id first_name last_name                email     phone          city
# 0   1       John       Doe     john@example.com  555-1234       Cordoba
# 1   2       Jane     Smith     jane@example.com  555-5678  Buenos Aires
# 2   3    Michael   Johnson  michael@example.com  555-9876  Buenos Aires
# 3   4      Emily  Williams    emily@example.com  555-6543       Cordoba
# 4   5      David     Brown    david@example.com  555-7890  Buenos Aires
# 5   6       John       Doe     john@example.com  555-1234       Cordoba
# 6   7       Jane     Smith     jane@example.com  555-5678  Buenos Aires
# 7   8    Michael   Johnson  michael@example.com  555-9876  Buenos Aires
# ...

# %%
# Sentencia para crear la tabla "customers"
create_table_query = '''
CREATE TABLE orders (
    id INT AUTO_INCREMENT PRIMARY KEY,
    customer_id INT,
    amount double
);
'''
cursor.execute(create_table_query)
# Sentencia para insertar 5 clientes
insert_customers_query = '''
INSERT INTO orders (customer_id, amount)
VALUES
    (1,5000),
    (2,6000),
    (1,15000);'''
cursor.execute(insert_customers_query)

# Confirmar los cambios en la base de datos
connection.commit()

# %%
customers_query = 'SELECT * FROM customers WHERE city IN ("Buenos Aires", "Codoba");'
df_query = pd.read_sql_query(customers_query, connection)
df_query.head()
# Out:
# <ipython-input-78-b41ca4bd0998>:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_query = pd.read_sql_query(customers_query, connection)
#    id first_name last_name                email     phone          city
# 0   2       Jane     Smith     jane@example.com  555-5678  Buenos Aires
# 1   3    Michael   Johnson  michael@example.com  555-9876  Buenos Aires
# 2   5      David     Brown    david@example.com  555-7890  Buenos Aires
# 3   7       Jane     Smith     jane@example.com  555-5678  Buenos Aires
# 4   8    Michael   Johnson  michael@example.com  555-9876  Buenos Aires

# %%
customers_query = 'SELECT city as provincia, COUNT(*) FROM customers GROUP BY city;'
df_query1 = pd.read_sql_query(customers_query, connection)
df_query1.head()
# Out:
# <ipython-input-80-000c854f23ac>:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_query1 = pd.read_sql_query(customers_query, connection)
#       provincia  COUNT(*)
# 0       Cordoba         4
# 1  Buenos Aires         6
